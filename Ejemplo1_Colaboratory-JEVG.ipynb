# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseEmmanuelVG/ArtificialVision/blob/main/Ejemplo1_Colaboratory-JEVG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # for image display


imagen=cv.imread("/content/Monedas.jpg",1)
cv2_imshow(imagen) # Colores invertido 
img_copy =np.copy(imagen)

print(imagen.dtype) #Tipo Matriz
print(imagen.shape[0]) # Alto
print(imagen.shape[1]) # Ancho
print(imagen.shape[2]) # Numero de canales
# Out:
# <PIL.Image.Image image mode=RGB size=643x574 at 0x7F93ECA398E0>
# uint8
# 574
# 643
# 3

# %%
gray_image = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
print(gray_image.dtype) #Tipo Matriz
print(gray_image.shape[0]) # Alto
print(gray_image.shape[1]) # Ancho
#print(gray_image.shape[2]) # Numero de canales
# Out:
# <PIL.Image.Image image mode=L size=643x574 at 0x7F93ECA4A970>
# uint8
# 574
# 643

# %%
import matplotlib.pyplot as plt
#cv.calcHist([img], channels, mask, bins, ranges)
hist = cv2.calcHist([gray_image], [0], None, [256], [0, 256]) 
plt.plot(hist)
